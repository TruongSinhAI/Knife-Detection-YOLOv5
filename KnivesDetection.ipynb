# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !pip install -r /content/yolov5/requirements.txt

# %%
''' train'''
# !python /content/yolov5/train.py  --batch-size 32 --epochs 85 --data /content/gdrive/MyDrive/KnivesDetection/data.yaml --cfg /content/gdrive/MyDrive/KnivesDetection/custom.yaml --name KnivesDetection
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=/content/gdrive/MyDrive/KnivesDetection/custom.yaml, data=/content/gdrive/MyDrive/KnivesDetection/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=85, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=KnivesDetection, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-227-ge4df1ec Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
#test
# !python /content/yolov5/detect.py --weights /content/gdrive/MyDrive/KnivesDetection/save/train/KnivesDetection2/weights/best.pt --img 640 --conf 0.2 --source /content/gdrive/MyDrive/KnivesDetection/images --save-csv
# Out:
# detect: weights=['/content/gdrive/MyDrive/KnivesDetection/save/train/KnivesDetection2/weights/best.pt'], source=/content/gdrive/MyDrive/KnivesDetection/images, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-227-ge4df1ec Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# custom summary: 140 layers, 5232324 parameters, 0 gradients, 14.3 GFLOPs
# image 1/3194 /content/gdrive/MyDrive/KnivesDetection/images/20220816_131030_jpg.rf.42f3edba46871bc7a54e809e218d1b48.jpg: 640x640 1 knife, 449.2ms
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/yolov5/runs '/content/gdrive/MyDrive/KnivesDetection/'
